# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from scipy.stats import unitary_group
from matplotlib import pyplot as plt
from ConcConvEigenVals import iterate_through_t, get_EV_and_plot

# %% [markdown]
# # Ecuaciones
# ### $ u(t) = diag(e^{i\theta_1t}, e^{i\theta_2t}, e^{i\theta_3t}) $ donde $t$ entre -1 y 1, intervalo 0.1 y $\theta_r constante$
#
# ### $ v = diag(e^{i\mu_1}, e^{i\mu_2}, e^{i\mu_3})$ donde $\mu_r$ estan entre $-\pi/2$ y $\pi/2$
# ### $w$ es una matriz unitaria
# ### $H = w.v.w^{-1}.u(t)$
# ### $ -i.log(EigenVals(H))$

# %% [markdown]
# # Genero $\theta$, $\mu$ y $W$ al azar
# Cada vez que se corre la siguiente celda se eligen valores al azar y se grafica

# %%
# N es la dimensión

eigenvalues, tita, mu, w = get_EV_and_plot(N=5)
# Out:
# thetas:
# [-0.33236433  1.2928149  -0.57359279  1.29914495 -1.36315611]
# mus:
# [ 1.32141162 -0.99929856 -1.23267063 -1.29290103  1.3942916 ]
# w:
# [[ 0.19277579-0.19596416j -0.65781387+0.15937231j -0.20048889+0.48741075j
#   -0.35597634-0.14363644j -0.2017877 +0.02197761j]
#  [-0.08308663-0.44068421j  0.30510555+0.0364989j   0.0301801 -0.11883417j
#   -0.48729776-0.56426266j  0.30516125-0.2011597j ]
#  [-0.00941153+0.07071673j -0.44655754+0.15099994j -0.05247511-0.70100793j
#   -0.25318423+0.09694687j  0.27318496+0.36110832j]
#  [ 0.28861719-0.38634088j -0.22899372-0.33464612j  0.2976156 +0.08006429j
#    0.11724855+0.38915219j  0.51703424-0.27480594j]
#  [ 0.66499467-0.20847799j  0.21844213+0.11446427j  0.01025522-0.34343312j
#   -0.1546795 +0.18489079j -0.50032251-0.16436403j]]

# %% [markdown]
# # Le puedo pasar $\theta$, $\mu$ y $W$ como parámetro, lo que no le paso lo genera al azar

# %%
N = 3
tita = np.array([
    -0.74,
    0.20,
    0.94
])
mu = np.array([
    -0.1,
    -1.3,
    -0.94
])
# La elijo al azar
w = np.matrix(unitary_group.rvs(N))

# %%
eigenvalues, tita, mu, w = get_EV_and_plot(
    tita=tita,
    mu=mu,
    w=w
)
# Out:
# thetas:
# [-0.33236433  1.2928149  -0.57359279  1.29914495 -1.36315611]
# mus:
# [ 1.32141162 -0.99929856 -1.23267063 -1.29290103  1.3942916 ]
# w:
# [[ 0.19277579-0.19596416j -0.65781387+0.15937231j -0.20048889+0.48741075j
#   -0.35597634-0.14363644j -0.2017877 +0.02197761j]
#  [-0.08308663-0.44068421j  0.30510555+0.0364989j   0.0301801 -0.11883417j
#   -0.48729776-0.56426266j  0.30516125-0.2011597j ]
#  [-0.00941153+0.07071673j -0.44655754+0.15099994j -0.05247511-0.70100793j
#   -0.25318423+0.09694687j  0.27318496+0.36110832j]
#  [ 0.28861719-0.38634088j -0.22899372-0.33464612j  0.2976156 +0.08006429j
#    0.11724855+0.38915219j  0.51703424-0.27480594j]
#  [ 0.66499467-0.20847799j  0.21844213+0.11446427j  0.01025522-0.34343312j
#   -0.1546795 +0.18489079j -0.50032251-0.16436403j]]

# %% [markdown]
# # Cargo algunos casos guardados en disco

# %%
# Cambiar k desde 1 a 2
k = 3
tita = np.load(f'data/tita_{k}.npy')
mu = np.load(f'data/mu_{k}.npy')
w = np.matrix(np.load(f'data/w_{k}.npy'))
tita[1] = 0.2
print('thetas:')
print(tita)
print('mus:')
print(mu)
print("w:")
print(w)
eigen_values, tita, mu, w = get_EV_and_plot(
    tita=tita,
    mu=mu,
    w=w
)
# Out:
# thetas:
# [-0.74  0.2   0.94]
# mus:
# [-0.1  -1.3  -0.94]
# w:
# [[ 0.4849909 -0.59200043j  0.16635866+0.06209527j -0.01557306+0.61850285j]
#  [ 0.35994614-0.25576133j  0.4541429 -0.48746701j -0.01761243-0.60070363j]
#  [-0.39196956+0.25632812j  0.67437435-0.26423161j -0.32276505+0.38971705j]]
# thetas:
# [-0.74  0.2   0.94]
# mus:
# [-0.1  -1.3  -0.94]
# w:
# [[ 0.4849909 -0.59200043j  0.16635866+0.06209527j -0.01557306+0.61850285j]
#  [ 0.35994614-0.25576133j  0.4541429 -0.48746701j -0.01761243-0.60070363j]
#  [-0.39196956+0.25632812j  0.67437435-0.26423161j -0.32276505+0.38971705j]]

# %% [markdown]
# # Guardo en disco
# ### Cuidado con el valor de k de no reemplazar guardados

# %%
k=3
np.save(f'data/tita_{k}.npy', tita)
np.save(f'data/mu_{k}.npy', mu)
np.save(f'data/w_{k}.npy', w)
